# %%
# input name
# drug_raw_temp = str(input("Enter name: "))
drug_raw_temp = 'proscar'
drug_name = drug_raw_temp.lower().replace(' ', '+').replace('-','+')

# Save file inactive_ingredient_list.txt
import os
print(drug_name)
drug_name_iig_file = drug_name + "_inactive_ingredient_list.txt"
drug_name_iig_filepath = os.path.join('iigdata', drug_name_iig_file)
    
# view data
import os
drug_name_csv = drug_name + "_inactive_ingredient_list.txt"
drug_name_csv_path = os.path.join('iigdata', drug_name_csv)

if os.path.isfile(drug_name_csv_path):
    import pandas as pd
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    df_iig = pd.read_csv(drug_name_csv_path)
else:
    print(f'{drug_name} is not in iigdata!')

df_iig.head()
# Out:
# proscar
#       MainDrug        NDC Strength           Formulation  \
# 0  finasteride  0006-0072     5 mg   tablet, film coated
# 1  finasteride  0006-0072     5 mg   tablet, film coated
# 2  finasteride  0006-0072     5 mg   tablet, film coated
# 3  finasteride  0006-0072     5 mg   tablet, film coated
# 4  finasteride  0006-0072     5 mg   tablet, film coated
#
#                           INGREDIENT_NAME
# 0                         DOCUSATE SODIUM
# 1                     FD&amp;C BLUE NO. 2
# 2                          ALUMINUM OXIDE
# 3                     LACTOSE MONOHYDRATE
# 4  HYDROXYPROPYL CELLULOSE (1600000 WAMW)

# %%
# view data
import os
iir_fda_data_name_file = "IIR_OCOMM.csv"
iir_fda_data_csv = os.path.join('iir_fda_data', iir_fda_data_name_file)

if os.path.isfile(iir_fda_data_csv):
    import pandas as pd
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    df_iir = pd.read_csv(iir_fda_data_csv)
else:
    print(f'{iir_fda_data_name_file} is not in folder!')

# %%
df_iir.head()
# Out:
#       INGREDIENT_NAME        ROUTE                        DOSAGE_FORM  \
# 0   .ALPHA.-TERPINEOL      TOPICAL                             LOTION
# 1  .ALPHA.-TOCOPHEROL       BUCCAL                      FILM, SOLUBLE
# 2  .ALPHA.-TOCOPHEROL  INTRAVENOUS  INJECTION, POWDER, FOR SUSPENSION
# 3  .ALPHA.-TOCOPHEROL         ORAL                            CAPSULE
# 4  .ALPHA.-TOCOPHEROL         ORAL                           SOLUTION
#
#    CAS_NUMBER        UNII  POTENCY_AMOUNT POTENCY_UNIT  \
# 0     98555.0  21334LVV8W           11.00         %w/w
# 1   1406184.0  H4N855PNZ1            0.07           mg
# 2   1406184.0  H4N855PNZ1            0.64           mg
# 3   1406184.0  H4N855PNZ1             NaN          NaN
# 4   1406184.0  H4N855PNZ1            1.05       mg/1ml
#
#    MAXIMUM_DAILY_EXPOSURE MAXIMUM_DAILY_EXPOSURE_UNIT RECORD_UPDATED
# 0                     NaN                         NaN            NaN
# 1                     NaN                         NaN            NaN
# 2                     NaN                         NaN            NaN
# 3                    16.0                          mg            NaN
# 4                     NaN                         NaN            NaN
